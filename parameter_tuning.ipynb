# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from helper import *

# %%
with open('useful_courses.pkl', 'rb') as f:
    eng_filtered_exams = pickle.load(f)

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 4, 6],
    'subsample': [0.8, 1.0]
}

# Call the function with the classifier, the parameter grid, and the dataframe
best_models = param_tuning(GradientBoostingClassifier, param_grid, eng_filtered_exams)
# Out:
#   0%|                                                                                           | 0/91 [00:00<?, ?it/s]
# 11 students pre-enrolled in AEP-4400
# 0 data point is nan during processing
# Sanity check passed
# 2 students dropped
# 1 students dropped in the train data
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
#   1%|▉                                                                                  | 1/91 [00:24<37:18, 24.87s/it]
# AEP-4400
# {'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 6, 'n_estimators': 50, 'subsample': 0.8}
# -0.36233845831938055
# 20 students pre-enrolled in AEP-5400
# 1 data point is nan during processing
# Sanity check passed
# 2 students dropped
# 1 students dropped in the train data
# ...

# %%
# with open('tuned_models/best_models_gb.p', 'wb') as fp:
#     pickle.dump(best_models, fp, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('tuned_models/best_models_gb.pkl', 'wb') as f:
    pickle.dump(best_models, f)

# %%
param_grid_lr = {
    'C': [0.01, 0.1, 1, 10],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga']
}
best_models_lr = param_tuning(LogisticRegression, param_grid_lr, eng_filtered_exams)
with open('tuned_models/best_models_lr.p', 'wb') as fp:
    pickle.dump(best_models_lr, fp, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|                                                                                           | 0/91 [00:00<?, ?it/s]C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 4, 6],
    'max_features': ['auto', 'sqrt', 'log2']
}
best_models_rf = param_tuning(RandomForestClassifier, param_grid_rf , eng_filtered_exams)
with open('tuned_models/best_models_rf.p', 'wb') as fp:
    pickle.dump(best_models_rf, fp, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|                                                                                           | 0/91 [00:00<?, ?it/s]
# 11 students pre-enrolled in AEP-4400
# 0 data point is nan during processing
# Sanity check passed
# 2 students dropped
# 1 students dropped in the train data
#   1%|▉                                                                                | 1/91 [00:43<1:04:58, 43.32s/it]
# AEP-4400
# {'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 6, 'n_estimators': 50}
# -0.556185893197279
# 20 students pre-enrolled in AEP-5400
# 1 data point is nan during processing
# Sanity check passed
# 2 students dropped
# 1 students dropped in the train data
#   2%|█▊                                                                               | 2/91 [01:26<1:04:34, 43.53s/it]
# AEP-5400
# {'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 6, 'n_estimators': 200}
# -0.4004662814715452
# 71 students pre-enrolled in BEE-5330
# ...
